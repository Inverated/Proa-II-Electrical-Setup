# %%
import numpy as np
import pandas as pd
import os

# %%
MAX_ROWS_PER_FILE = 500000

# %%
file_name = "data_20260612-164950.csv"
df = pd.read_csv(file_name)

# %%
print(df.head())
print(df.shape)
# Out:
#    counter  timediff_us    ch0    ch1    ch2    ch3    ch4    ch5    ch6  ch7
# 0    28867          868  32820  32691  32634  32780  32779  32784  30696  290
# 1    28868          865  32818  32682  32691  32779  32780  32785  30695  283
# 2    28869          868  32835  32699  32642  32780  32780  32782  30695  289
# 3    28870          866  32849  32701  32712  32779  32779  32782  30698  288
# 4    28871          866  32832  32715  32656  32779  32780  32783  30696  288
# (4107985, 10)

# %%
def split_df(df, max_rows=MAX_ROWS_PER_FILE):
    df_list = []
    for i in range(0, len(df), max_rows):
        df_list.append(df.iloc[i:i + max_rows])
    return df_list

# %%
df_list = split_df(df)

# %%
rows = 0
for df in df_list:
    print(df.shape)
    rows += df.shape[0]

print(rows)
print("Number of splits:", len(df_list))
# Out:
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (107985, 10)
# 4107985
# Number of splits: 9

# %%
for i, df_part in enumerate(df_list):
    output_file_name = f"{file_name.split('.csv')[0]}_part_{i+1}.csv"
    df_part.to_csv(output_file_name, index=False)
    print(f"Saved {output_file_name} with shape {df_part.shape}")
print("All files saved successfully.")
# Out:
# Saved data_20260612-164950_part_1.csv with shape (500000, 10)
# Saved data_20260612-164950_part_2.csv with shape (500000, 10)
# Saved data_20260612-164950_part_3.csv with shape (500000, 10)
# Saved data_20260612-164950_part_4.csv with shape (500000, 10)
# Saved data_20260612-164950_part_5.csv with shape (500000, 10)
# Saved data_20260612-164950_part_6.csv with shape (500000, 10)
# Saved data_20260612-164950_part_7.csv with shape (500000, 10)
# Saved data_20260612-164950_part_8.csv with shape (500000, 10)
# Saved data_20260612-164950_part_9.csv with shape (107985, 10)
# All files saved successfully.
