# %%
import numpy as np
import pandas as pd
import os

# %%
MAX_ROWS_PER_FILE = 500000

# %%
file_name = "data_20260612-153706.csv"
df = pd.read_csv(file_name)

# %%
print(df.head())
print(df.shape)
# Out:
#    counter  timediff_us    ch0    ch1    ch2    ch3    ch4    ch5    ch6  ch7
# 0    13423          867  32791  32629  32651  32778  32781  32783  30742  299
# 1    13424          865  32775  32677  32700  32778  32781  32783  30740  289
# 2    13425          871  32806  32718  32671  32779  32781  32783  30743  288
# 3    13426          866  32839  32703  32702  32778  32780  32783  30742  288
# 4    13427          866  32845  32669  32723  32780  32782  32782  30743  287
# (4087910, 10)

# %%
def split_df(df, max_rows=MAX_ROWS_PER_FILE):
    df_list = []
    for i in range(0, len(df), max_rows):
        df_list.append(df.iloc[i:i + max_rows])
    return df_list

# %%
df_list = split_df(df)

# %%
rows = 0
for df in df_list:
    print(df.shape)
    rows += df.shape[0]

print(rows)
print("Number of splits:", len(df_list))
# Out:
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (87910, 10)
# 4087910
# Number of splits: 9

# %%
for i, df_part in enumerate(df_list):
    output_file_name = f"{file_name.split('.csv')[0]}_part_{i+1}.csv"
    df_part.to_csv(output_file_name, index=False)
    print(f"Saved {output_file_name} with shape {df_part.shape}")
print("All files saved successfully.")
# Out:
# Saved data_20260612-153706_part_1.csv with shape (500000, 10)
# Saved data_20260612-153706_part_2.csv with shape (500000, 10)
# Saved data_20260612-153706_part_3.csv with shape (500000, 10)
# Saved data_20260612-153706_part_4.csv with shape (500000, 10)
# Saved data_20260612-153706_part_5.csv with shape (500000, 10)
# Saved data_20260612-153706_part_6.csv with shape (500000, 10)
# Saved data_20260612-153706_part_7.csv with shape (500000, 10)
# Saved data_20260612-153706_part_8.csv with shape (500000, 10)
# Saved data_20260612-153706_part_9.csv with shape (87910, 10)
# All files saved successfully.
