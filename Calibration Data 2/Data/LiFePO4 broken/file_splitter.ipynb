# %%
import numpy as np
import pandas as pd
import os

# %%
MAX_ROWS_PER_FILE = 500000

# %%
file_name = "data_20260608-164406.csv"
df = pd.read_csv(file_name)

# %%
print(df.head())
print(df.shape)
# Out:
#    counter  timediff_us    ch0    ch1    ch2    ch3    ch4    ch5    ch6  ch7
# 0    18802          863  32776  32811  32732  32780  32780  32782  28103  288
# 1    18803          866  32775  32789  32642  32779  32781  32783  28100  286
# 2    18804          865  32777  32807  32720  32779  32781  32783  28100  287
# 3    18805          871  32776  32819  32721  32779  32780  32781  28103  288
# 4    18806          866  32776  32802  32657  32778  32781  32783  28103  288
# (3456911, 10)

# %%
def split_df(df, max_rows=MAX_ROWS_PER_FILE):
    df_list = []
    for i in range(0, len(df), max_rows):
        df_list.append(df.iloc[i:i + max_rows])
    return df_list

# %%
df_list = split_df(df)

# %%
rows = 0
for df in df_list:
    print(df.shape)
    rows += df.shape[0]

print(rows)
print("Number of splits:", len(df_list))
# Out:
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (500000, 10)
# (456911, 10)
# 3456911
# Number of splits: 7

# %%
for i, df_part in enumerate(df_list):
    output_file_name = f"{file_name.split('.csv')[0]}_part_{i+1}.csv"
    df_part.to_csv(output_file_name, index=False)
    print(f"Saved {output_file_name} with shape {df_part.shape}")
print("All files saved successfully.")
# Out:
# Saved data_20260608-164406_part_1.csv with shape (500000, 10)
# Saved data_20260608-164406_part_2.csv with shape (500000, 10)
# Saved data_20260608-164406_part_3.csv with shape (500000, 10)
# Saved data_20260608-164406_part_4.csv with shape (500000, 10)
# Saved data_20260608-164406_part_5.csv with shape (500000, 10)
# Saved data_20260608-164406_part_6.csv with shape (500000, 10)
# Saved data_20260608-164406_part_7.csv with shape (456911, 10)
# All files saved successfully.
